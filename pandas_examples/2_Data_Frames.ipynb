# %%
import pandas as pd

f = open('./dataset/test.csv')
f_data = f.read()
f_lines = f_data.split('\n')
print f_lines[0]
print f_lines[1]
d_frame = pd.DataFrame([f_lines[1].split(',')], columns= f_lines[0].split(','))
d_frame
# Out:
# longitude,latitude,housing_median_age,total_rooms,total_bedrooms,population,households,median_income,median_house_value,ocean_proximity
# -122.23,37.88,41.0,880.0,129.0,322.0,126.0,8.3252,452600.0,NEAR BAY
#   longitude latitude housing_median_age total_rooms total_bedrooms population  \
# 0   -122.23    37.88               41.0       880.0          129.0      322.0
#
#   households median_income median_house_value ocean_proximity
# 0      126.0        8.3252           452600.0        NEAR BAY

# %%
#Using dict

data_dict = {'Name':['Tom', 'Jack', 'Steve', 'Ricky'],'Age':[28,34,29,42]}
dt_frame = pd.DataFrame(data_dict) 
dt_frame
# Out:
#    Age   Name
# 0   28    Tom
# 1   34   Jack
# 2   29  Steve
# 3   42  Ricky

# %%
# Using list of dict

dict_list = [{'key': 123, 'data1': 234}, {'key':456, 'data2': 789}]
dtl_frame = pd.DataFrame(dict_list)
dtl_frame
# Out:
#    data1  data2  key
# 0  234.0    NaN  123
# 1    NaN  789.0  456

# %%
# Using csv

path = './dataset/test.csv'
dframe = pd.DataFrame.from_csv(path)
dframe
# Out:
# /home/etguser/myexp/pandas/lib/python2.7/site-packages/ipykernel_launcher.py:4: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   after removing the cwd from sys.path.
#            latitude  housing_median_age  total_rooms  total_bedrooms  \
# longitude
# -122.23       37.88                41.0        880.0           129.0
# -122.22       37.86                21.0       7099.0          1106.0
# -122.24       37.85                52.0       1467.0           190.0
# -122.25       37.85                52.0       1274.0           235.0
# -122.25       37.85                52.0       1627.0           280.0
# -122.25       37.85                52.0        919.0           213.0
# -122.25       37.84                52.0       2535.0           489.0
# -122.25       37.84                52.0       3104.0           687.0
# ...

# %%
# Accessing data from top

dframe.head(3)
# Out:
#            latitude  housing_median_age  total_rooms  total_bedrooms  \
# longitude
# -122.23       37.88                41.0        880.0           129.0
# -122.22       37.86                21.0       7099.0          1106.0
# -122.24       37.85                52.0       1467.0           190.0
#
#            population  households  median_income  median_house_value  \
# longitude
# -122.23         322.0       126.0         8.3252            452600.0
# -122.22        2401.0      1138.0         8.3014            358500.0
# -122.24         496.0       177.0         7.2574            352100.0
#
#           ocean_proximity
# longitude
# -122.23          NEAR BAY
# -122.22          NEAR BAY
# -122.24          NEAR BAY

# %%
# Accesing data from bottom/last

dframe.tail(3)
# Out:
#            latitude  housing_median_age  total_rooms  total_bedrooms  \
# longitude
# -122.26       37.85                52.0       3503.0           752.0
# -122.26       37.85                52.0       2491.0           474.0
# -122.26       37.84                52.0        696.0           191.0
#
#            population  households  median_income  median_house_value  \
# longitude
# -122.26        1504.0       734.0         3.2705            241800.0
# -122.26        1098.0       468.0         3.0750            213500.0
# -122.26         345.0       174.0         2.6736            191300.0
#
#           ocean_proximity
# longitude
# -122.26          NEAR BAY
# -122.26          NEAR BAY
# -122.26          NEAR BAY

# %%
dframe.describe()
# Out:
#         latitude  housing_median_age  total_rooms  total_bedrooms  \
# count  14.000000           14.000000    14.000000       14.000000
# mean   37.849286           48.285714  2421.500000      468.000000
# std     0.010716            8.721579  1648.765541      285.120218
# min    37.840000           21.000000   696.000000      129.000000
# 25%    37.840000           52.000000  1322.250000      218.500000
# 50%    37.850000           52.000000  2346.500000      454.000000
# 75%    37.850000           52.000000  2966.750000      681.500000
# max    37.880000           52.000000  7099.000000     1106.000000
#
#         population   households  median_income  median_house_value
# count    14.000000    14.000000      14.000000           14.000000
# mean    972.857143   454.285714       4.441643       290921.428571
# std     586.751927   291.094600       2.080443        71264.557796
# min     322.000000   126.000000       2.080400       191300.000000
# ...

# %%
#accessing row
#dframe[]

dframe.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-9492766f2734> in <module>()
#       2 #dframe[]
#       3
# ----> 4 dframe['-122.26']
#       5
#
# /home/etguser/myexp/pandas/local/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# /home/etguser/myexp/pandas/local/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# ...
